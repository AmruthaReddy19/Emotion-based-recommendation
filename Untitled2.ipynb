# %%
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = pd.read_csv('labelledData.csv')
lemma = WordNetLemmatizer()
stop_words = stopwords.words('english')

# %%
df.head()
# Out:
#    Unnamed: 0                                              Tweet  Flag  \
# 0           3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1           7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2          10  b'@returnofprince2 This is like saying diabete...     1
# 3          14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4          15  b'RT @GoSatvik: What concerns me today is the ...     1
#
#        Tags
# 0  Skincare
# 1  Skincare
# 2  diabetes
# 3  skincare
# 4    asthma

# %%
def text_prep(x: str) -> list:
    
    corp = str(x).lower() 
    corp = re.sub('[^a-zA-Z]+',' ', corp).strip() 
    tokens = word_tokenize(corp)
    words = [t for t in tokens if t not in stop_words]
    lemmatize = [lemma.lemmatize(w) for w in words]
    return lemmatize

# %%
preprocess_tag = [text_prep(i) for i in df['Tweet']]
df["preprocess_txt"] = preprocess_tag

# %%
df.head()
# Out:
#    Unnamed: 0                                              Tweet  Flag  \
# 0           3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1           7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2          10  b'@returnofprince2 This is like saying diabete...     1
# 3          14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4          15  b'RT @GoSatvik: What concerns me today is the ...     1
#
#        Tags                                     preprocess_txt
# 0  Skincare  [b, coba, cek, ini, deh, skintific, best, sell...
# 1  Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...
# 2  diabetes  [b, returnofprince, like, saying, diabetes, fr...
# 3  skincare  [b, rt, kpop, herald, cha, eun, woo, offclastr...
# 4    asthma  [b, rt, gosatvik, concern, today, increasing, ...

# %%
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df['total_len'] = df['preprocess_txt'].map(lambda x: len(x))

# %%
df.head()
# Out:
#    Unnamed: 0                                              Tweet  Flag  \
# 0           3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1           7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2          10  b'@returnofprince2 This is like saying diabete...     1
# 3          14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4          15  b'RT @GoSatvik: What concerns me today is the ...     1
#
#        Tags                                     preprocess_txt  total_len
# 0  Skincare  [b, coba, cek, ini, deh, skintific, best, sell...         25
# 1  Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 2  diabetes  [b, returnofprince, like, saying, diabetes, fr...         11
# 3  skincare  [b, rt, kpop, herald, cha, eun, woo, offclastr...         23
# 4    asthma  [b, rt, gosatvik, concern, today, increasing, ...         17

# %%
file = open('negative-words.txt', 'r')
neg_words = file.read().split()
file = open('positive-words.txt', 'r')
pos_words = file.read().split()

# %%
num_pos = df['preprocess_txt'].map(lambda x: len([i for i in x if i in pos_words]))
df['pos_count'] = num_pos
num_neg = df['preprocess_txt'].map(lambda x: len([i for i in x if i in neg_words]))
df['neg_count'] = num_neg

# %%
df.head()
# Out:
#    Unnamed: 0                                              Tweet  Flag  \
# 0           3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1           7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2          10  b'@returnofprince2 This is like saying diabete...     1
# 3          14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4          15  b'RT @GoSatvik: What concerns me today is the ...     1
#
#        Tags                                     preprocess_txt  total_len  \
# 0  Skincare  [b, coba, cek, ini, deh, skintific, best, sell...         25
# 1  Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 2  diabetes  [b, returnofprince, like, saying, diabetes, fr...         11
# 3  skincare  [b, rt, kpop, herald, cha, eun, woo, offclastr...         23
# 4    asthma  [b, rt, gosatvik, concern, today, increasing, ...         17
#
#    pos_count  neg_count
# 0          1          0
# 1          0          0
# 2          1          1
# 3          2          0
# 4          0          2

# %%
df['sentiment'] = round((df['pos_count'] - df['neg_count']) / df['total_len'], 2)

# %%
df
# Out:
#       Unnamed: 0                                              Tweet  Flag  \
# 0              3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1              7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2             10  b'@returnofprince2 This is like saying diabete...     1
# 3             14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4             15  b'RT @GoSatvik: What concerns me today is the ...     1
# ...          ...                                                ...   ...
# 1327        3543  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 1328        3548  b'RT @korysstorm: it\xe2\x80\x99s crazy how yo...     1
# 1329        3551  b'@ShopeeID sama inii Skincare Kit IVnya Bioaq...     1
# 1330        3555  b'\xe0\xae\x9a\xe0\xae\xb0\xe0\xaf\x8d\xe0\xae...     1
# 1331        3558  b'RT @korysstorm: it\xe2\x80\x99s crazy how yo...     1
#
#           Tags                                     preprocess_txt  total_len  \
# 0     Skincare  [b, coba, cek, ini, deh, skintific, best, sell...         25
# 1     Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 2     diabetes  [b, returnofprince, like, saying, diabetes, fr...         11
# 3     skincare  [b, rt, kpop, herald, cha, eun, woo, offclastr...         23
# 4       asthma  [b, rt, gosatvik, concern, today, increasing, ...         17
# ...        ...                                                ...        ...
# 1327  Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 1328  skincare  [b, rt, korysstorm, xe, x, x, crazy, skincare,...         18
# 1329  Skincare  [b, shopeeid, sama, inii, skincare, kit, ivnya...         12
# 1330  diabetes  [b, xe, xae, x, xe, xae, xb, xe, xaf, x, xe, x...        254
# 1331  skincare  [b, rt, korysstorm, xe, x, x, crazy, skincare,...         18
#
#       pos_count  neg_count  sentiment
# 0             1          0       0.04
# 1             0          0       0.00
# 2             1          1       0.00
# 3             2          0       0.09
# 4             0          2      -0.12
# ...         ...        ...        ...
# 1327          0          0       0.00
# 1328          1          1       0.00
# 1329          0          0       0.00
# 1330          0          0       0.00
# 1331          1          1       0.00
#
# [1332 rows x 9 columns]

# %%
#Using Positive and Negative Word Counts – With Semi Normalization to calculate Sentiment Score

# %%
df['semi_normalization'] = round((df['pos_count'] - df['neg_count']) / (df['neg_count']+1), 2)

# %%
df
# Out:
#       Unnamed: 0                                              Tweet  Flag  \
# 0              3  b'Coba cek ini, deh: "SKINTIFIC Best Seller Re...     1
# 1              7  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 2             10  b'@returnofprince2 This is like saying diabete...     1
# 3             14  b"RT @Kpop_Herald: Cha Eun-woo of @offclASTRO ...     1
# 4             15  b'RT @GoSatvik: What concerns me today is the ...     1
# ...          ...                                                ...   ...
# 1327        3543  b'RT @EBBahboh: How to \xe0\xb8\xad\xe0\xb9\x8...     1
# 1328        3548  b'RT @korysstorm: it\xe2\x80\x99s crazy how yo...     1
# 1329        3551  b'@ShopeeID sama inii Skincare Kit IVnya Bioaq...     1
# 1330        3555  b'\xe0\xae\x9a\xe0\xae\xb0\xe0\xaf\x8d\xe0\xae...     1
# 1331        3558  b'RT @korysstorm: it\xe2\x80\x99s crazy how yo...     1
#
#           Tags                                     preprocess_txt  total_len  \
# 0     Skincare  [b, coba, cek, ini, deh, skintific, best, sell...         25
# 1     Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 2     diabetes  [b, returnofprince, like, saying, diabetes, fr...         11
# 3     skincare  [b, rt, kpop, herald, cha, eun, woo, offclastr...         23
# 4       asthma  [b, rt, gosatvik, concern, today, increasing, ...         17
# ...        ...                                                ...        ...
# 1327  Skincare  [b, rt, ebbahboh, xe, xb, xad, xe, xb, x, xe, ...        206
# 1328  skincare  [b, rt, korysstorm, xe, x, x, crazy, skincare,...         18
# 1329  Skincare  [b, shopeeid, sama, inii, skincare, kit, ivnya...         12
# 1330  diabetes  [b, xe, xae, x, xe, xae, xb, xe, xaf, x, xe, x...        254
# 1331  skincare  [b, rt, korysstorm, xe, x, x, crazy, skincare,...         18
#
#       pos_count  neg_count  sentiment  semi_normalization
# 0             1          0       0.04                1.00
# 1             0          0       0.00                0.00
# 2             1          1       0.00                0.00
# 3             2          0       0.09                2.00
# 4             0          2      -0.12               -0.67
# ...         ...        ...        ...                 ...
# 1327          0          0       0.00                0.00
# 1328          1          1       0.00                0.00
# 1329          0          0       0.00                0.00
# 1330          0          0       0.00                0.00
# 1331          1          1       0.00                0.00
#
# [1332 rows x 10 columns]
