# %%
import pandas as pd

# %%
final_data= pd.read_csv('final.csv')

# %%
final_data.head()
# Out:
#    Unnamed: 0                   id                       Time  \
# 0           0  1591420715043291136  2023-02-14 17:55:37+00:00
# 1           1  1591420715043291136  2023-02-14 17:55:35+00:00
# 2           2  1591420715043291136  2023-02-14 17:55:33+00:00
# 3           3  1591420715043291136  2023-02-14 17:55:31+00:00
# 4           4  1591420715043291136  2023-02-14 17:55:27+00:00
#
#                                                Tweet
# 0  b'RT @Un_mi2471: Join New Meditation Method. A...
# 1  b'RT @Un_mi2471: Join New Meditation Method. A...
# 2  b'RT @Un_mi2471: Join New Meditation Method. A...
# 3  b'RT @Un_mi2471: Join New Meditation Method. A...
# 4  b'RT @Un_mi2471: Join New Meditation Method. A...

# %%
final_data.drop_duplicates(subset="Tweet",keep=False, inplace=True)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30577 entries, 6 to 65376
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30577 non-null  int64
#  1   id          30577 non-null  object
#  2   Time        30577 non-null  object
#  3   Tweet       30577 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
final_data
# Out:
#        Unnamed: 0                   id                       Time  \
# 6               6           4047408077  2023-02-14 17:55:24+00:00
# 10             10           3320788901  2023-02-14 17:55:18+00:00
# 15             15           4039664782  2023-02-14 17:55:08+00:00
# 18             18             62240256  2023-02-14 17:55:00+00:00
# 75             75  1510427631249887238  2023-02-14 17:52:16+00:00
# ...           ...                  ...                        ...
# 65371        2883           1476742116  2023-02-14 15:52:23+00:00
# 65372        2884            334714751  2023-02-14 15:52:16+00:00
# 65373        2885   729753956843323392  2023-02-14 15:52:15+00:00
# 65375        2887             23563381  2023-02-14 15:52:06+00:00
# 65376        2888  1359489880812847106  2023-02-14 15:51:59+00:00
#
#                                                    Tweet
# 6                       b'@oljog1 Had one for my asthma'
# 10     b'@Native3rd Deep breathing, mindfulness, and ...
# ...

# %%
final_data.to_csv('final_data.csv')
