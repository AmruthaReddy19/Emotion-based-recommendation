# %%
import pandas as pd

# %%
df=pd.read_csv('CleanedDataset.csv')

# %%
df['Tweet']=df['Tweet'].str.lower()

# %%
df
# Out:
#       Unnamed: 0            id                       Time  \
# 0              0  1.578530e+18  2023-02-13 17:09:44+00:00
# 1              1  4.904996e+07  2023-02-13 15:34:08+00:00
# 2              2  9.234178e+07  2023-02-13 13:57:31+00:00
# 3              3  1.179430e+18  2023-02-13 11:38:54+00:00
# 4              4  8.566819e+08  2023-02-13 01:57:45+00:00
# ...          ...           ...                        ...
# 7475        7475  7.051626e+08  2023-02-05 11:45:11+00:00
# 7476        7476  6.354304e+07  2023-02-05 11:35:22+00:00
# 7477        7477  1.273950e+18  2023-02-05 11:30:20+00:00
# 7478        7478  3.306546e+09  2023-02-05 11:26:45+00:00
# 7479        7479  1.282360e+18  2023-02-05 11:14:11+00:00
#
#                                                   Tweet  \
# 0     b'runny nose tear eyes fever headache loss of ...
# 1     b'@katkinneywrites i have hot/cold sometimes. ...
# 2     b'cytomegalovirus colitis - complication when ...
# 3     b'@fatalkci l know otli and matli for nausea a...
# 4     b'went from a fever to a cough to a sore throa...
# ...                                                 ...
# 7475  b'#nowplaying jump (mega banton) by dengue fev...
# 7476  b"rt @chris_c_chapman: blood counts still very...
# 7477  b'rt @shukladeepak73: different activities by ...
# 7478  b'dengue: 1 more dies, 5 patients hospitalised...
# 7479  b"if only your name rhymed with dengue shock s...
#
#                                                    prep  \
# 0     runny nose tear eyes fever headache loss of ap...
# 1     @katkinneywrites i have hot/cold sometimes. us...
# 2     cytomegalovirus colitis - complication when cd...
# 3     @fatalkci l know otli and matli for nausea and...
# 4     went from a fever to a cough to a sore throat ...
# ...                                                 ...
# 7475  #nowplaying jump (mega banton) by dengue fever...
# 7476  rt @chris_c_chapman: blood counts still very l...
# 7477  rt @shukladeepak73: different activities by bc...
# 7478  dengue: 1 more dies, 5 patients hospitalised\n...
# 7479  if only your name rhymed with dengue shock syn...
#
#                                          cleaned_tweets
# 0     runny nose tear eyes fever headache loss of ap...
# 1      i have hot/cold sometimes. usually cold means...
# 2     cytomegalovirus colitis - complication when cd...
# 3      l know otli and matli for nausea and vomiting...
# 4     went from a fever to a cough to a sore throat ...
# ...                                                 ...
# 7475   jump (mega banton) by dengue fever riddim  on...
# 7476  rt : blood counts still very low. but they hav...
# 7477  rt : different activities by bccf under embed ...
# 7478  dengue: 1 more dies, 5 patients hospitalised\n \n
# 7479  if only your name rhymed with dengue shock syn...
#
# [7480 rows x 6 columns]

# %%
diseases=['asthma','autism','dengue','fever','flu','nausea','anxiety','sprain','stroke','obesity']

# %%
diseases
# Out:
# ['asthma',
#  'autism',
#  'dengue',
#  'fever',
#  'flu',
#  'nausea',
#  'anxiety',
#  'sprain',
#  'stroke',
#  'obesity']

# %%
tw=[]
for i in df['Tweet']:
    tw.append(i)

# %%
len(tw)
# Out:
# 7480

# %%
tag=[]
flag=False
for i in range(0,len(tw)):
    for j in range(0,len(diseases)):
        if(tw[i].find(diseases[j])>0):
            tag.append(diseases[j])
            flag=True
            break
    if(flag != True):
        tag.append('NIL')
    flag=False

# %%
len(tag)
# Out:
# 7480

# %%
df['tags']=tag

# %%
df
# Out:
#       Unnamed: 0            id                       Time  \
# 0              0  1.578530e+18  2023-02-13 17:09:44+00:00
# 1              1  4.904996e+07  2023-02-13 15:34:08+00:00
# 2              2  9.234178e+07  2023-02-13 13:57:31+00:00
# 3              3  1.179430e+18  2023-02-13 11:38:54+00:00
# 4              4  8.566819e+08  2023-02-13 01:57:45+00:00
# ...          ...           ...                        ...
# 7475        7475  7.051626e+08  2023-02-05 11:45:11+00:00
# 7476        7476  6.354304e+07  2023-02-05 11:35:22+00:00
# 7477        7477  1.273950e+18  2023-02-05 11:30:20+00:00
# 7478        7478  3.306546e+09  2023-02-05 11:26:45+00:00
# 7479        7479  1.282360e+18  2023-02-05 11:14:11+00:00
#
#                                                   Tweet  \
# 0     b'runny nose tear eyes fever headache loss of ...
# 1     b'@katkinneywrites i have hot/cold sometimes. ...
# 2     b'cytomegalovirus colitis - complication when ...
# 3     b'@fatalkci l know otli and matli for nausea a...
# 4     b'went from a fever to a cough to a sore throa...
# ...                                                 ...
# 7475  b'#nowplaying jump (mega banton) by dengue fev...
# 7476  b"rt @chris_c_chapman: blood counts still very...
# 7477  b'rt @shukladeepak73: different activities by ...
# 7478  b'dengue: 1 more dies, 5 patients hospitalised...
# 7479  b"if only your name rhymed with dengue shock s...
#
#                                                    prep  \
# 0     runny nose tear eyes fever headache loss of ap...
# 1     @katkinneywrites i have hot/cold sometimes. us...
# 2     cytomegalovirus colitis - complication when cd...
# 3     @fatalkci l know otli and matli for nausea and...
# 4     went from a fever to a cough to a sore throat ...
# ...                                                 ...
# 7475  #nowplaying jump (mega banton) by dengue fever...
# 7476  rt @chris_c_chapman: blood counts still very l...
# 7477  rt @shukladeepak73: different activities by bc...
# 7478  dengue: 1 more dies, 5 patients hospitalised\n...
# 7479  if only your name rhymed with dengue shock syn...
#
#                                          cleaned_tweets    tags
# 0     runny nose tear eyes fever headache loss of ap...   fever
# 1      i have hot/cold sometimes. usually cold means...   fever
# 2     cytomegalovirus colitis - complication when cd...   fever
# 3      l know otli and matli for nausea and vomiting...   fever
# 4     went from a fever to a cough to a sore throat ...   fever
# ...                                                 ...     ...
# 7475   jump (mega banton) by dengue fever riddim  on...  dengue
# 7476  rt : blood counts still very low. but they hav...  dengue
# 7477  rt : different activities by bccf under embed ...  dengue
# 7478  dengue: 1 more dies, 5 patients hospitalised\n \n  dengue
# 7479  if only your name rhymed with dengue shock syn...  dengue
#
# [7480 rows x 7 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#              id                       Time  \
# 0  1.578530e+18  2023-02-13 17:09:44+00:00
# 1  4.904996e+07  2023-02-13 15:34:08+00:00
# 2  9.234178e+07  2023-02-13 13:57:31+00:00
# 3  1.179430e+18  2023-02-13 11:38:54+00:00
# 4  8.566819e+08  2023-02-13 01:57:45+00:00
#
#                                                Tweet  \
# 0  b'runny nose tear eyes fever headache loss of ...
# 1  b'@katkinneywrites i have hot/cold sometimes. ...
# 2  b'cytomegalovirus colitis - complication when ...
# 3  b'@fatalkci l know otli and matli for nausea a...
# 4  b'went from a fever to a cough to a sore throa...
#
#                                                 prep  \
# 0  runny nose tear eyes fever headache loss of ap...
# 1  @katkinneywrites i have hot/cold sometimes. us...
# 2  cytomegalovirus colitis - complication when cd...
# 3  @fatalkci l know otli and matli for nausea and...
# 4  went from a fever to a cough to a sore throat ...
#
#                                       cleaned_tweets   tags
# 0  runny nose tear eyes fever headache loss of ap...  fever
# 1   i have hot/cold sometimes. usually cold means...  fever
# 2  cytomegalovirus colitis - complication when cd...  fever
# 3   l know otli and matli for nausea and vomiting...  fever
# 4  went from a fever to a cough to a sore throat ...  fever

# %%
df.to_csv('labelled_data.csv')

# %%
df['tags'].value_counts()
# Out:
# fever      750
# nausea     750
# sprain     750
# stroke     750
# anxiety    750
# flu        750
# obesity    750
# autism     750
# asthma     750
# dengue     730
# Name: tags, dtype: int64

# %%
df
# Out:
#                 id                       Time  \
# 0     1.578530e+18  2023-02-13 17:09:44+00:00
# 1     4.904996e+07  2023-02-13 15:34:08+00:00
# 2     9.234178e+07  2023-02-13 13:57:31+00:00
# 3     1.179430e+18  2023-02-13 11:38:54+00:00
# 4     8.566819e+08  2023-02-13 01:57:45+00:00
# ...            ...                        ...
# 7475  7.051626e+08  2023-02-05 11:45:11+00:00
# 7476  6.354304e+07  2023-02-05 11:35:22+00:00
# 7477  1.273950e+18  2023-02-05 11:30:20+00:00
# 7478  3.306546e+09  2023-02-05 11:26:45+00:00
# 7479  1.282360e+18  2023-02-05 11:14:11+00:00
#
#                                                   Tweet  \
# 0     b'runny nose tear eyes fever headache loss of ...
# 1     b'@katkinneywrites i have hot/cold sometimes. ...
# 2     b'cytomegalovirus colitis - complication when ...
# 3     b'@fatalkci l know otli and matli for nausea a...
# 4     b'went from a fever to a cough to a sore throa...
# ...                                                 ...
# 7475  b'#nowplaying jump (mega banton) by dengue fev...
# 7476  b"rt @chris_c_chapman: blood counts still very...
# 7477  b'rt @shukladeepak73: different activities by ...
# 7478  b'dengue: 1 more dies, 5 patients hospitalised...
# 7479  b"if only your name rhymed with dengue shock s...
#
#                                                    prep  \
# 0     runny nose tear eyes fever headache loss of ap...
# 1     @katkinneywrites i have hot/cold sometimes. us...
# 2     cytomegalovirus colitis - complication when cd...
# 3     @fatalkci l know otli and matli for nausea and...
# 4     went from a fever to a cough to a sore throat ...
# ...                                                 ...
# 7475  #nowplaying jump (mega banton) by dengue fever...
# 7476  rt @chris_c_chapman: blood counts still very l...
# 7477  rt @shukladeepak73: different activities by bc...
# 7478  dengue: 1 more dies, 5 patients hospitalised\n...
# 7479  if only your name rhymed with dengue shock syn...
#
#                                          cleaned_tweets    tags
# 0     runny nose tear eyes fever headache loss of ap...   fever
# 1      i have hot/cold sometimes. usually cold means...   fever
# 2     cytomegalovirus colitis - complication when cd...   fever
# 3      l know otli and matli for nausea and vomiting...   fever
# 4     went from a fever to a cough to a sore throat ...   fever
# ...                                                 ...     ...
# 7475   jump (mega banton) by dengue fever riddim  on...  dengue
# 7476  rt : blood counts still very low. but they hav...  dengue
# 7477  rt : different activities by bccf under embed ...  dengue
# 7478  dengue: 1 more dies, 5 patients hospitalised\n \n  dengue
# 7479  if only your name rhymed with dengue shock syn...  dengue
#
# [7480 rows x 6 columns]

# %%
df_dengue1=pd.DataFrame(df_dengue)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df_dengue1=pd.DataFrame(df_dengue)
#
# NameError: name 'df_dengue' is not defined

# %%
df_dengue1
# Out:
#                         id                       Time  \
# 21658            276271211  2023-02-14 17:58:29+00:00
# 21659             28222035  2023-02-14 17:43:11+00:00
# 21660  1608303387103092736  2023-02-14 17:39:01+00:00
# 21662             18649572  2023-02-14 17:16:51+00:00
# 21663  1089517380907266049  2023-02-14 17:09:51+00:00
# ...                    ...                        ...
# 22754            705162643  2023-02-05 11:45:11+00:00
# 22755             63543042  2023-02-05 11:35:22+00:00
# 22756  1273954059867701251  2023-02-05 11:30:20+00:00
# 22757           3306545726  2023-02-05 11:26:45+00:00
# 22759  1282362054200958978  2023-02-05 11:14:11+00:00
#
#                                                    Tweet  \
# 21658  b'rt @davidulin: an honor to publish four new ...
# 21659  b'an honor to publish four new poems by @clmer...
# 21660  b'rt @kcoh999: dengue infections on the rise; ...
# 21662  b'all i listen to is alton ellis &amp; dengue ...
# 21663  b'@longchar_amenla it sucks but theres not muc...
# ...                                                  ...
# 22754  b'#nowplaying jump (mega banton) by dengue fev...
# 22755  b"rt @chris_c_chapman: blood counts still very...
# 22756  b'rt @shukladeepak73: different activities by ...
# 22757  b'dengue: 1 more dies, 5 patients hospitalised...
# 22759  b"if only your name rhymed with dengue shock s...
#
#                                         Processed_Tweets    tags
# 21658  b'rt:honorpublishfournewpoemsmorning.\n\n''den...  dengue
# 21659  b'anhonorpublishfournewpoemsmorning.\n\n''deng...  dengue
# 21660  b'rt:dengueinfectionsrise;outbreakclose,people...  dengue
# 21662     b'alllistenaltonellis&amp;denguedenguedengue.'  dengue
# 21663     b'suckstheresmuch,livingalonedenguefarfaraw...  dengue
# ...                                                  ...     ...
# 22754  b'nowplayingjump(megabanton)denguefeverriddiml...  dengue
# 22755  b''rt:bloodcountsstilllow.startedgo,showsdengu...  dengue
# 22756  b'rt:differentactivitiesbccfembedproject.\nmal...  dengue
# 22757  b'dengue:dies,patientshospitalised\ndenguebang...  dengue
# 22759  b''namerhymeddengueshocksyndrome-inducingconsu...  dengue
#
# [730 rows x 5 columns]

# %%
df_fever1=pd.DataFrame(df_fever)

# %%
df_nausea1=pd.DataFrame(df_nausea)

# %%
df_sprain1=pd.DataFrame(df_sprain)

# %%
df_stroke1=pd.DataFrame(df_dengue)

# %%
df_anxiety1=pd.DataFrame(df_dengue)

# %%
df_flu1=pd.DataFrame(df_dengue)

# %%
df_obesity1=pd.DataFrame(df_obesity)

# %%
df_autism1=pd.DataFrame(df_autism)

# %%
df_dengue1=pd.DataFrame(df_dengue)

# %%
type(df_asthma1)
# Out:
# pandas.core.frame.DataFrame

# %%
(df_dengue['tags']=='dengue').sum()
# Out:
# 730

# %%
df_dengue1
# Out:
#                         id                       Time  \
# 21658            276271211  2023-02-14 17:58:29+00:00
# 21659             28222035  2023-02-14 17:43:11+00:00
# 21660  1608303387103092736  2023-02-14 17:39:01+00:00
# 21662             18649572  2023-02-14 17:16:51+00:00
# 21663  1089517380907266049  2023-02-14 17:09:51+00:00
# ...                    ...                        ...
# 22754            705162643  2023-02-05 11:45:11+00:00
# 22755             63543042  2023-02-05 11:35:22+00:00
# 22756  1273954059867701251  2023-02-05 11:30:20+00:00
# 22757           3306545726  2023-02-05 11:26:45+00:00
# 22759  1282362054200958978  2023-02-05 11:14:11+00:00
#
#                                                    Tweet  \
# 21658  b'rt @davidulin: an honor to publish four new ...
# 21659  b'an honor to publish four new poems by @clmer...
# 21660  b'rt @kcoh999: dengue infections on the rise; ...
# 21662  b'all i listen to is alton ellis &amp; dengue ...
# 21663  b'@longchar_amenla it sucks but theres not muc...
# ...                                                  ...
# 22754  b'#nowplaying jump (mega banton) by dengue fev...
# 22755  b"rt @chris_c_chapman: blood counts still very...
# 22756  b'rt @shukladeepak73: different activities by ...
# 22757  b'dengue: 1 more dies, 5 patients hospitalised...
# 22759  b"if only your name rhymed with dengue shock s...
#
#                                         Processed_Tweets    tags
# 21658  b'rt:honorpublishfournewpoemsmorning.\n\n''den...  dengue
# 21659  b'anhonorpublishfournewpoemsmorning.\n\n''deng...  dengue
# 21660  b'rt:dengueinfectionsrise;outbreakclose,people...  dengue
# 21662     b'alllistenaltonellis&amp;denguedenguedengue.'  dengue
# 21663     b'suckstheresmuch,livingalonedenguefarfaraw...  dengue
# ...                                                  ...     ...
# 22754  b'nowplayingjump(megabanton)denguefeverriddiml...  dengue
# 22755  b''rt:bloodcountsstilllow.startedgo,showsdengu...  dengue
# 22756  b'rt:differentactivitiesbccfembedproject.\nmal...  dengue
# 22757  b'dengue:dies,patientshospitalised\ndenguebang...  dengue
# 22759  b''namerhymeddengueshocksyndrome-inducingconsu...  dengue
#
# [730 rows x 5 columns]

# %%
data['tags'].value_counts()
# Out:
# fever      750
# nausea     750
# sprain     750
# stroke     750
# anxiety    750
# flu        750
# obesity    750
# autism     750
# asthma     750
# dengue     730
# Name: tags, dtype: int64

# %%
data.to_csv('equalData.csv')
