# %%
import pandas as pd

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, words
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, words
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer 
from nltk import pos_tag 
from textblob import TextBlob 
from wordcloud import WordCloud
import numpy as np 
import re 
import string 
import glob 
from nltk import pos_tag

# %%
import nltk
from nltk.corpus import stopwords
from tqdm import tqdm
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/imheister/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/imheister/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tweets_df = pd.read_csv('data.csv')

# %%
tweets_df
# Out:
#        Unnamed: 0                                              Tweet    Tags
# 0               0  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 1               1  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 2               2  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 3               3  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 4               4  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# ...           ...                                                ...     ...
# 65372       65372  b'This tweet is to remind myself that whatever...     NIL
# 65373       65373  b'@nainboruto No I disagree with the merging o...     NIL
# 65374       65374  b'RT @wweisawesome123: I am a young man with a...     NIL
# 65375       65375  b'i took a couple autism quizzes online today....     NIL
# 65376       65376  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...     NIL
#
# [65377 rows x 3 columns]

# %%
tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'Tweet', 'Tags'], dtype='object')

# %%
tweets_df=tweets_df.drop(columns=['Unnamed: 0'])

# %%
tweets_df.head()
# Out:
#                                                Tweet    Tags
# 0  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 1  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 2  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 3  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 4  b'RT @Un_mi2471: Join New Meditation Method. A...  asthma

# %%
#To remove Punctuation like link, emoji, etc
def preprocessTweets(tweet):
  tweet=tweet.lower()
  #Remove Urls
  tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet)
  #remove @reference and # from tweet
  tweet = re.sub(r'\@\w+|\#|\d+','',tweet)
  #remove stopword
  tweet_token =word_tokenize(tweet) #Convert string to token
  filtered_words =  [w for w in tweet_token if w not in stop_words]
  #remove Punctuation
  unpunctuated_words = [char for char in filtered_words if char not in string.punctuation]
  unpunctuated_words = ' '.join(unpunctuated_words)

  

  return "".join(unpunctuated_words)

# Function to obtain adjectives from tweets
def getAdjective(tweet):
  tweet = word_tokenize(tweet)
  tweet = [word for(word, tag) in pos_tag(tweet) if tag =="JJ" ]
  return " ".join(tweet)

# %%
stop_words = list(stopwords.words('english'))

user_stop_words = ['2020', 'year', 'many', 'much', 'amp', 'next', 'cant', 'wont', 'hadnt',
                    'havent', 'hasnt', 'isnt', 'shouldnt', 'couldnt', 'wasnt', 'werent',
                    'mustnt', '’', '...', '..', '.', '.....', '....', 'been…', 'one', 'two',
                    'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'aht',
                    've', 'next']
alphabets = list(string.ascii_lowercase)
stop_word = stop_words + user_stop_words + alphabets   
word_list = words.words()

# %%
# function to return words to their base form using Lemmatizer
def preprocessTweetsSentiments(tweet):
  tweet_tokens= word_tokenize(tweet)
  lemmatizer = WordNetLemmatizer()
  lemma_words = [lemmatizer.lemmatize(w) for w in tweet_tokens]
  return " ".join(lemma_words)

# %%
tweets_df
# Out:
#                                                    Tweet    Tags  \
# 0      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 1      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 2      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 3      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 4      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# ...                                                  ...     ...
# 65372  b'This tweet is to remind myself that whatever...     NIL
# 65373  b'@nainboruto No I disagree with the merging o...     NIL
# 65374  b'RT @wweisawesome123: I am a young man with a...     NIL
# 65375  b'i took a couple autism quizzes online today....     NIL
# 65376  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...     NIL
#
#                                         Processed_Tweets  \
# 0      b'rt join new meditation method diseases curab...
# 1      b'rt join new meditation method diseases curab...
# 2      b'rt join new meditation method diseases curab...
# 3      b'rt join new meditation method diseases curab...
# 4      b'rt join new meditation method diseases curab...
# ...                                                  ...
# 65372  b'this tweet remind whatever autism moment new...
# 65373  b disagree merging aspergers autism one umbrel...
# 65374  b'rt young man autism\nand special needs \nbot...
# 65375  b took couple autism quizzes online today mode...
# 65376                                              b ...
#
#              Tweets_Adjectives  \
# 0      new curable like-\npcos
# 1      new curable like-\npcos
# 2      new curable like-\npcos
# 3      new curable like-\npcos
# 4      new curable like-\npcos
# ...                        ...
# 65372               b'this new
# 65373                 umbrella
# 65374     young special \nboth
# 65375             online bunch
# 65376
#
#                                         Tweets_Sentiment  Subjectivity  \
# 0       join new meditation method disease curable li...      0.454545
# 1       join new meditation method disease curable li...      0.454545
# 2       join new meditation method disease curable li...      0.454545
# 3       join new meditation method disease curable li...      0.454545
# 4       join new meditation method disease curable li...      0.454545
# ...                                                  ...           ...
# 65372  this tweet remind whatever autism moment new d...      0.454545
# 65373  b disagree merging aspergers autism one umbrel...      0.000000
# 65374   young man autism\nand special need \nboth par...      0.623810
# 65375  b took couple autism quiz online today moderat...      0.700000
# 65376                                              b ...      0.000000
#
#        Polarity Sentiment
# 0      0.136364  Positive
# 1      0.136364  Positive
# 2      0.136364  Positive
# 3      0.136364  Positive
# 4      0.136364  Positive
# ...         ...       ...
# 65372  0.136364  Positive
# 65373  0.000000   Neutral
# 65374  0.419048  Positive
# 65375  0.000000   Neutral
# 65376  0.000000   Neutral
#
# [65377 rows x 8 columns]

# %%
tweets_df['Processed_Tweets']= tweets_df['Tweet'].apply(preprocessTweets)

# %%
tweets_df['Tweets_Adjectives']= tweets_df['Processed_Tweets'].apply(getAdjective)

# %%
# function to return words to their base form using Lemmatizer
def preprocessTweetsSentiments(tweet):
  tweet_tokens= word_tokenize(tweet)
  lemmatizer = WordNetLemmatizer()
  lemma_words = [lemmatizer.lemmatize(w) for w in tweet_tokens]
  return " ".join(lemma_words)

# %%
tweets_df['Tweets_Sentiment'] = tweets_df['Processed_Tweets'].apply(preprocessTweetsSentiments)

# %%
tweets_df
# Out:
#                                                    Tweet    Tags  \
# 0      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 1      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 2      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 3      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 4      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# ...                                                  ...     ...
# 65372  b'This tweet is to remind myself that whatever...     NIL
# 65373  b'@nainboruto No I disagree with the merging o...     NIL
# 65374  b'RT @wweisawesome123: I am a young man with a...     NIL
# 65375  b'i took a couple autism quizzes online today....     NIL
# 65376  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...     NIL
#
#                                         Processed_Tweets  \
# 0      b'rt join new meditation method diseases curab...
# 1      b'rt join new meditation method diseases curab...
# 2      b'rt join new meditation method diseases curab...
# 3      b'rt join new meditation method diseases curab...
# 4      b'rt join new meditation method diseases curab...
# ...                                                  ...
# 65372  b'this tweet remind whatever autism moment new...
# 65373  b disagree merging aspergers autism one umbrel...
# 65374  b'rt young man autism\nand special needs \nbot...
# 65375  b took couple autism quizzes online today mode...
# 65376                                              b ...
#
#              Tweets_Adjectives  \
# 0      new curable like-\npcos
# 1      new curable like-\npcos
# 2      new curable like-\npcos
# 3      new curable like-\npcos
# 4      new curable like-\npcos
# ...                        ...
# 65372               b'this new
# 65373                 umbrella
# 65374     young special \nboth
# 65375             online bunch
# 65376
#
#                                         Tweets_Sentiment  Subjectivity  \
# 0      b'rt join new meditation method disease curabl...      0.454545
# 1      b'rt join new meditation method disease curabl...      0.454545
# 2      b'rt join new meditation method disease curabl...      0.454545
# 3      b'rt join new meditation method disease curabl...      0.454545
# 4      b'rt join new meditation method disease curabl...      0.454545
# ...                                                  ...           ...
# 65372  b'this tweet remind whatever autism moment new...      0.454545
# 65373  b disagree merging aspergers autism one umbrel...      0.000000
# 65374  b'rt young man autism\nand special need \nboth...      0.623810
# 65375  b took couple autism quiz online today moderat...      0.700000
# 65376                                              b ...      0.000000
#
#        Polarity Sentiment
# 0      0.136364  Positive
# 1      0.136364  Positive
# 2      0.136364  Positive
# 3      0.136364  Positive
# 4      0.136364  Positive
# ...         ...       ...
# 65372  0.136364  Positive
# 65373  0.000000   Neutral
# 65374  0.419048  Positive
# 65375  0.000000   Neutral
# 65376  0.000000   Neutral
#
# [65377 rows x 8 columns]

# %%
tweets_long_string = tweets_df['Tweets_Adjectives'].tolist()
tweets_list=[]
for item in tweets_long_string:
    item = item.split()
    for i in item:
        tweets_list.append(i)

# %%
# Use the Built-in Python Collections module to determine Word frequency
from collections import Counter
counts = Counter(tweets_list)
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df.columns = ['Words', 'Count']
df.sort_values(by='Count', ascending=False, inplace=True)

# %%
df.head()
# Out:
#       Words  Count
# 981     \n-   4931
# 5      b'rt   4340
# 26     high   3275
# 95       rt   3192
# 1141  \n\n-   2511

# %%
#Removing tweet and reTweet symbol/text
for i in range(0,len(tweets_df['Tweets_Sentiment'])):
    s=tweets_df['Tweets_Sentiment'][i]
    s=s.replace("b'rt","")
    s=s.replace("b'","")
    tweets_df['Tweets_Sentiment'][i]=s
# Out:
# /var/folders/xw/jdlnt25d1vs3q5srndt_2g580000gn/T/ipykernel_94076/1844280663.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['Tweets_Sentiment'][i]=s

# %%
#calculating Subjectivity score
def getSubjectivity(tweet):
  return TextBlob(tweet).sentiment.subjectivity

def getPolarity(tweet):
  return TextBlob(tweet).sentiment.polarity
def getSentimentTextBlob(polarity):
  if polarity<0:
    return "Negative"
  elif polarity ==0:
    return "Neutral"
  else:
    return "Positive"

# %%
tweets_df['Subjectivity']= tweets_df['Tweets_Sentiment'].apply(getSubjectivity)
tweets_df['Polarity'] = tweets_df['Tweets_Sentiment'].apply(getPolarity)
tweets_df['Sentiment'] = tweets_df['Polarity'].apply(getSentimentTextBlob)

# %%
tweets_df
# Out:
#                                                    Tweet    Tags  \
# 0      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 1      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 2      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 3      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# 4      b'RT @Un_mi2471: Join New Meditation Method. A...  asthma
# ...                                                  ...     ...
# 65372  b'This tweet is to remind myself that whatever...     NIL
# 65373  b'@nainboruto No I disagree with the merging o...     NIL
# 65374  b'RT @wweisawesome123: I am a young man with a...     NIL
# 65375  b'i took a couple autism quizzes online today....     NIL
# 65376  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...     NIL
#
#                                         Processed_Tweets  \
# 0      b'rt join new meditation method diseases curab...
# 1      b'rt join new meditation method diseases curab...
# 2      b'rt join new meditation method diseases curab...
# 3      b'rt join new meditation method diseases curab...
# 4      b'rt join new meditation method diseases curab...
# ...                                                  ...
# 65372  b'this tweet remind whatever autism moment new...
# 65373  b disagree merging aspergers autism one umbrel...
# 65374  b'rt young man autism\nand special needs \nbot...
# 65375  b took couple autism quizzes online today mode...
# 65376                                              b ...
#
#              Tweets_Adjectives  \
# 0      new curable like-\npcos
# 1      new curable like-\npcos
# 2      new curable like-\npcos
# 3      new curable like-\npcos
# 4      new curable like-\npcos
# ...                        ...
# 65372               b'this new
# 65373                 umbrella
# 65374     young special \nboth
# 65375             online bunch
# 65376
#
#                                         Tweets_Sentiment  Subjectivity  \
# 0       join new meditation method disease curable li...      0.454545
# 1       join new meditation method disease curable li...      0.454545
# 2       join new meditation method disease curable li...      0.454545
# 3       join new meditation method disease curable li...      0.454545
# 4       join new meditation method disease curable li...      0.454545
# ...                                                  ...           ...
# 65372  this tweet remind whatever autism moment new d...      0.454545
# 65373  b disagree merging aspergers autism one umbrel...      0.000000
# 65374   young man autism\nand special need \nboth par...      0.623810
# 65375  b took couple autism quiz online today moderat...      0.700000
# 65376                                              b ...      0.000000
#
#        Polarity Sentiment
# 0      0.136364  Positive
# 1      0.136364  Positive
# 2      0.136364  Positive
# 3      0.136364  Positive
# 4      0.136364  Positive
# ...         ...       ...
# 65372  0.136364  Positive
# 65373  0.000000   Neutral
# 65374  0.419048  Positive
# 65375  0.000000   Neutral
# 65376  0.000000   Neutral
#
# [65377 rows x 8 columns]

# %%
tweets_df['Sentiment'].value_counts()
# Out:
# Positive    26127
# Neutral     25669
# Negative    13581
# Name: Sentiment, dtype: int64
