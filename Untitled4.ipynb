# %%
import pandas as pd
import re
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords,words
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tweets_df=pd.read_csv('final_data.csv')

# %%
tweets_df
# Out:
#        Unnamed: 0  Unnamed: 0.1                   id  \
# 0               6             6           4047408077
# 1              10            10           3320788901
# 2              15            15           4039664782
# 3              18            18             62240256
# 4              75            75  1510427631249887238
# ...           ...           ...                  ...
# 30572       65371          2883           1476742116
# 30573       65372          2884            334714751
# 30574       65373          2885   729753956843323392
# 30575       65375          2887             23563381
# 30576       65376          2888  1359489880812847106
#
#                             Time  \
# 0      2023-02-14 17:55:24+00:00
# 1      2023-02-14 17:55:18+00:00
# 2      2023-02-14 17:55:08+00:00
# 3      2023-02-14 17:55:00+00:00
# 4      2023-02-14 17:52:16+00:00
# ...                          ...
# 30572  2023-02-14 15:52:23+00:00
# 30573  2023-02-14 15:52:16+00:00
# 30574  2023-02-14 15:52:15+00:00
# 30575  2023-02-14 15:52:06+00:00
# 30576  2023-02-14 15:51:59+00:00
#
#                                                    Tweet
# 0                       b'@oljog1 Had one for my asthma'
# 1      b'@Native3rd Deep breathing, mindfulness, and ...
# 2      b'@FordF35022 @black_gato_xy @krassenstein Als...
# 3      b'#GenericTiotropium Inhalation Powder Capsule...
# 4      b'@TracyElrod5 And those were all useless. We ...
# ...                                                  ...
# 30572  b'Learning #Disabilities and Disorders: Types ...
# 30573  b'This tweet is to remind myself that whatever...
# 30574  b'@nainboruto No I disagree with the merging o...
# 30575  b'i took a couple autism quizzes online today....
# 30576  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...
#
# [30577 rows x 5 columns]

# %%
tweets_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
tweets_df.drop('Unnamed: 0.1',axis=1,inplace=True)

# %%
tweets_df.head()
# Out:
#                     id                       Time  \
# 0           4047408077  2023-02-14 17:55:24+00:00
# 1           3320788901  2023-02-14 17:55:18+00:00
# 2           4039664782  2023-02-14 17:55:08+00:00
# 3             62240256  2023-02-14 17:55:00+00:00
# 4  1510427631249887238  2023-02-14 17:52:16+00:00
#
#                                                Tweet
# 0                   b'@oljog1 Had one for my asthma'
# 1  b'@Native3rd Deep breathing, mindfulness, and ...
# 2  b'@FordF35022 @black_gato_xy @krassenstein Als...
# 3  b'#GenericTiotropium Inhalation Powder Capsule...
# 4  b'@TracyElrod5 And those were all useless. We ...

# %%
stop_words = list(stopwords.words('english'))

# %%
def preprocessTweets(tweet):
  tweet=tweet.lower()
  #Remove Urls
  tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet)
  #remove @reference and # from tweet
  tweet = re.sub(r'\@\w+|\#|\d+','',tweet)
  #remove stopword
  tweet_token =word_tokenize(tweet) #Convert string to token
  filtered_words =  [w for w in tweet_token if w not in stop_words]
  

  

  return "".join(filtered_words)

# %%
tweets_df['Processed_Tweets']= tweets_df['Tweet'].apply(preprocessTweets)

# %%
tweets_df
# Out:
#                         id                       Time  \
# 0               4047408077  2023-02-14 17:55:24+00:00
# 1               3320788901  2023-02-14 17:55:18+00:00
# 2               4039664782  2023-02-14 17:55:08+00:00
# 3                 62240256  2023-02-14 17:55:00+00:00
# 4      1510427631249887238  2023-02-14 17:52:16+00:00
# ...                    ...                        ...
# 30572           1476742116  2023-02-14 15:52:23+00:00
# 30573            334714751  2023-02-14 15:52:16+00:00
# 30574   729753956843323392  2023-02-14 15:52:15+00:00
# 30575             23563381  2023-02-14 15:52:06+00:00
# 30576  1359489880812847106  2023-02-14 15:51:59+00:00
#
#                                                    Tweet  \
# 0                       b'@oljog1 Had one for my asthma'
# 1      b'@Native3rd Deep breathing, mindfulness, and ...
# 2      b'@FordF35022 @black_gato_xy @krassenstein Als...
# 3      b'#GenericTiotropium Inhalation Powder Capsule...
# 4      b'@TracyElrod5 And those were all useless. We ...
# ...                                                  ...
# 30572  b'Learning #Disabilities and Disorders: Types ...
# 30573  b'This tweet is to remind myself that whatever...
# 30574  b'@nainboruto No I disagree with the merging o...
# 30575  b'i took a couple autism quizzes online today....
# 30576  b'@csimons3 @hollie110 @JesusIsLord2222 @Arlen...
#
#                                         Processed_Tweets
# 0                                           b'oneasthma'
# 1      b'deepbreathing,mindfulness,listeningbodylearn...
# 2      b'alsoseatbeltlaws,cancertreatments,bloodpress...
# 3      b'generictiotropiuminhalationpowdercapsules$.\...
# 4      b'useless.needednmasksunavailable.however,even...
# ...                                                  ...
# 30572  b'learningdisabilitiesdisorders:typeslearningd...
# 30573  b'thistweetremindwhateverautismmomentnewdaysee...
# 30574  b'disagreemergingaspergersautismoneumbrelladia...
# 30575  b'tookcoupleautismquizzesonlinetoday.moderate....
# 30576                                              b'...
#
# [30577 rows x 4 columns]

# %%
tweets_df.to_csv('predata.csv')
